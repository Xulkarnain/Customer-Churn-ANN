# %%
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from keras import layers
# Out:
# d:\Btech_CS\Python\venv\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
X_train = np.load("D:/Customer-Churn-ANN/data/X_train.npy")
X_test = np.load("D:/Customer-Churn-ANN/data/X_test.npy")
y_train = np.load("D:/Customer-Churn-ANN/data/y_train.npy")
y_test = np.load("D:/Customer-Churn-ANN/data/y_test.npy")

print(X_train.shape)
print(X_test.shape)
# Out:
# (5634, 23)
# (1409, 23)

# %% [markdown]
# ## Model Architecture
